# %%
import numpy as np
import matplotlib.pyplot as plt
# !pip3 install sympy
from sympy import *
import sympy

# %%
mat1 = np.random.random(9).reshape(3,3)
mat1
# Out:
# array([[0.60754984, 0.56059262, 0.55123066],
#        [0.85803003, 0.82422579, 0.28876725],
#        [0.95931332, 0.53086769, 0.49521327]])

# %%
np.linalg.det(mat1)
# Out:
# -0.11282657397310834

# %%
np.linalg.eig(mat1)
# Out:
# (array([ 1.8697456 , -0.21868884,  0.27593212]),
#  array([[-0.52869287, -0.67857913,  0.27987363],
#         [-0.59977452,  0.38509536, -0.75217385],
#         [-0.60062831,  0.62548535,  0.59657795]]))

# %%
np.linalg.eigvals(mat1)
# Out:
# array([ 1.8697456 , -0.21868884,  0.27593212])

# %%
x, y, z = sympy.symbols('x y z')

# %%
sympy.diff(tan(2*x), x)
# Out:
# 2*tan(2*x)**2 + 2

# %%
diff(x**2)
# Out:
# 2*x

# %%
simplify(diff(tan(y * cos(exp(x**2))), x))
# Out:
# -2*x*y*exp(x**2)*sin(exp(x**2))/cos(y*cos(exp(x**2)))**2

# %%
simplify()

# %%
integrate(exp(-2*x), (x, sqrt(1), oo))
# Out:
# exp(-2)/2

# %%
M = Matrix([[1, -1], [3, 4], [0, 2]])
M
# Out:
# Matrix([
# [1, -1],
# [3,  4],
# [0,  2]])

# %%
shape(M)
# Out:
# (3, 2)

# %%
M = Matrix([[1, 43, 5, 3], [2, 12, 4, 8], [-4, -3, 8, 4]])
M
# Out:
# Matrix([
# [ 1, 43, 5, 3],
# [ 2, 12, 4, 8],
# [-4, -3, 8, 4]])

# %%
M.rref()
# Out:
# (Matrix([
#  [1, 0, 0, 1050/529],
#  [0, 1, 0,  -76/529],
#  [0, 0, 1,  761/529]]),
#  (0, 1, 2))

# %%
lmbda , t= sympy.symbols('lmbda t')

# %%
mat1_sympy = Matrix(mat1)
mat1_sympy
# Out:
# Matrix([
# [0.607549835362937, 0.560592620522417, 0.551230655059692],
# [  0.8580300314056, 0.824225787699097, 0.288767251351895],
# [0.959313320317775, 0.530867694549452, 0.495213270115864]])

# %%
mat1_sympy - lmbda*eye(3)
# Out:
# Matrix([
# [0.607549835362937 - lmbda,         0.560592620522417,         0.551230655059692],
# [          0.8580300314056, 0.824225787699097 - lmbda,         0.288767251351895],
# [        0.959313320317775,         0.530867694549452, 0.495213270115864 - lmbda]])

# %%
Determinant(mat1_sympy - lmbda*eye(3))
# Out:
# Determinant(Matrix([
# [0.607549835362937 - lmbda,         0.560592620522417,         0.551230655059692],
# [          0.8580300314056, 0.824225787699097 - lmbda,         0.288767251351895],
# [        0.959313320317775,         0.530867694549452, 0.495213270115864 - lmbda]]))

# %%
simplify(Determinant(mat1_sympy - lmbda*eye(3)))
# Out:
# -lmbda**3 + 1.9269888931779*lmbda**2 - 0.0466871112417873*lmbda - 0.112826573973108

# %%
solve(simplify(Determinant(mat1_sympy - lmbda*eye(3))), lmbda)
# Out:
# [-0.218688836674303 + 0.e-22*I,
#  0.275932124940298 - 0.e-23*I,
#  1.86974560491191 - 0.e-21*I]

# %%
from sympy import symbols
from sympy.plotting import plot
x = symbols('x')
p1 = plot(sin(x) *cos(x), show=False)
p2 = plot(log(x), show=False)

p1.append(p2[0])
p1
p1.show()

# %%
p2 = plot(1/(x), show=False)
p2.show()

# %%
from sympy import symbols
from sympy.plotting import plot3d
x, y = symbols('x y')

# %%
plot3d(cos(x)*sin(y)-2, (x, -5, 5), (y, -5, 5))

# %%
plot3d(cos(x)*sin(y*2)*exp(2*x)-2, (x, -5, 5), (y, -5, 5));

# %%
# Out:
# 1
